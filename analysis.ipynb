# %%
import requests
import json
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = input("Enter the URL of the page to scrape: ")
r = requests.get(url)
soup = bs(r.content)
json_fotmob = json.loads(soup.find('script', attrs={'id': '__NEXT_DATA__'}).contents[0])

# %%
# General match info
json_fotmob['props']['pageProps']['general']
# Out:
# {'matchId': '4756697',
#  'matchName': 'Botafogo RJ-vs-Carabobo FC_Tue, Apr 8, 2025, 22:00 UTC',
#  'matchRound': '2',
#  'teamColors': {'darkMode': {'home': '#ffffff', 'away': '#943521'},
#   'lightMode': {'home': '#181818', 'away': '#551515'},
#   'fontDarkMode': {'home': 'rgba(29, 29, 29, 1.0)',
#    'away': 'rgba(255, 255, 255, 1.0)'},
#   'fontLightMode': {'home': 'rgba(255, 255, 255, 1.0)',
#    'away': 'rgba(255, 255, 255, 1.0)'}},
#  'leagueId': 898417,
#  'leagueName': 'Copa Libertadores Grp. A',
#  'leagueRoundName': '2',
#  'parentLeagueId': 45,
#  'countryCode': 'INT-2',
#  'parentLeagueName': 'Copa Libertadores',
#  'parentLeagueSeason': '2025',
#  'parentLeagueTopScorerLink': 'https://data.fotmob.com/stats/45/season/25464/goals.json',
#  'parentLeagueTournamentId': 25464,
#  'homeTeam': {'name': 'Botafogo RJ', 'id': 8517},
#  'awayTeam': {'name': 'Carabobo FC', 'id': 49681},
#  'coverageLevel': 'xG',
#  'matchTimeUTC': 'Tue, Apr 8, 2025, 22:00 UTC',
#  'matchTimeUTCDate': '2025-04-08T22:00:00.000Z',
#  'started': True,
#  'finished': True}

# %%
matchRound = int(json_fotmob['props']['pageProps']['general']['matchRound'])
matchRound
# Out:
# 2

# %%
type(matchRound)
# Out:
# int

# %%
h_team = json_fotmob['props']['pageProps']['general']['homeTeam']['name']

# %%
json_fotmob['props']['pageProps']['general']['awayTeam']['name']
# Out:
# 'Carabobo FC'

# %%
df = pd.DataFrame(json_fotmob['props']['pageProps']['content']['playerStats'])
df
# Out:
#                 188652                                             281240  \
# name             Allan                                  Gonzalo Mastriani
# id              188652                                             281240
# optaId          119765                                             153330
# teamId            8517                                               8517
# teamName      Botafogo                                           Botafogo
# isGoalkeeper     False                                              False
# stats               []  [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap             []  [{'id': 2798416929, 'eventType': 'Miss', 'team...
# funFacts            []                                                 []
#
#                         423496  \
# name          Marcel Guaramato
# id                      423496
# optaId                  166518
# teamId                   49681
# teamName           Carabobo FC
# isGoalkeeper             False
# stats                       []
# shotmap                     []
# funFacts                    []
#
#                                                          428672  \
# name                                                Alex Telles
# id                                                       428672
# optaId                                                   152590
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                          501636  \
# name                                         Jefferson Savarino
# id                                                       501636
# optaId                                                   196666
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2798416179, 'eventType': 'AttemptSaved...
# funFacts      [{'key': 'fun_fact_low_touches', 'fallback': '...
#
#                                                          593211  \
# name                                           Gustavo Gonzalez
# id                                                       593211
# optaId                                                   196304
# teamId                                                    49681
# teamName                                            Carabobo FC
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2798415517, 'eventType': 'Miss', 'team...
# funFacts                                                     []
#
#                                                          634868  \
# name                                             Marlon Freitas
# id                                                       634868
# optaId                                                   219357
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                          641140  \
# name                                           Robert Hernandez
# id                                                       641140
# optaId                                                   149237
# teamId                                                    49681
# teamName                                            Carabobo FC
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                          657969  \
# name                                          Alexander Barboza
# id                                                       657969
# optaId                                                   213531
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2798422359, 'eventType': 'Miss', 'team...
# funFacts      [{'key': 'fun_fact_motm', 'fallback': 'Alexand...
#
#                                                          749834  ...  \
# name                                                John Victor  ...
# id                                                       749834  ...
# optaId                                                   221389  ...
# teamId                                                     8517  ...
# teamName                                               Botafogo  ...
# isGoalkeeper                                               True  ...
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...  ...
# shotmap                                                      []  ...
# funFacts                                                     []  ...
#
#                                                         1436176  \
# name                                                Mateo Ponte
# id                                                      1436176
# optaId                                                   609049
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                         1453231  \
# name                                             Ezequiel Neira
# id                                                      1453231
# optaId                                                   502487
# teamId                                                    49681
# teamName                                            Carabobo FC
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                         1476545   1578668  \
# name                                                   Cuiabano    Newton
# id                                                      1476545   1578668
# optaId                                                   560441    608580
# teamId                                                     8517      8517
# teamName                                               Botafogo  Botafogo
# isGoalkeeper                                              False     False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...        []
# shotmap       [{'id': 2798437109, 'eventType': 'Miss', 'team...        []
# funFacts                                                     []        []
#
#                    1611001                                            1615062  \
# name          Freiver Ruiz                                      Franner Lopez
# id                 1611001                                            1615062
# optaId              485122                                             612930
# teamId               49681                                              49681
# teamName       Carabobo FC                                        Carabobo FC
# isGoalkeeper         False                                              False
# stats                   []  [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                 []                                                 []
# funFacts                []                                                 []
#
#                1626265       1732667            1732679          1739032
# name              Kaue  Kauan Lindes  Sebastian Mendoza  Fernando Garcia
# id             1626265       1732667            1732679          1739032
# optaId          608581        646823             654211           693358
# teamId            8517          8517              49681            49681
# teamName      Botafogo      Botafogo        Carabobo FC      Carabobo FC
# isGoalkeeper     False         False              False             True
# stats               []            []                 []               []
# shotmap             []            []                 []               []
# funFacts            []            []                 []               []
#
# [9 rows x 46 columns]

# %%
df = df.T
df.head()
# Out:
#                       name      id  optaId teamId     teamName isGoalkeeper  \
# 188652               Allan  188652  119765   8517     Botafogo        False
# 281240   Gonzalo Mastriani  281240  153330   8517     Botafogo        False
# 423496    Marcel Guaramato  423496  166518  49681  Carabobo FC        False
# 428672         Alex Telles  428672  152590   8517     Botafogo        False
# 501636  Jefferson Savarino  501636  196666   8517     Botafogo        False
#
#                                                     stats  \
# 188652                                                 []
# 281240  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 423496                                                 []
# 428672  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 501636  [{'title': 'Top stats', 'key': 'top_stats', 's...
#
#                                                   shotmap  \
# 188652                                                 []
# 281240  [{'id': 2798416929, 'eventType': 'Miss', 'team...
# 423496                                                 []
# 428672                                                 []
# 501636  [{'id': 2798416179, 'eventType': 'AttemptSaved...
#
#                                                  funFacts
# 188652                                                 []
# 281240                                                 []
# 423496                                                 []
# 428672                                                 []
# 501636  [{'key': 'fun_fact_low_touches', 'fallback': '...

# %%
df['player_id'] = df.index
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#                  name      id  optaId teamId     teamName isGoalkeeper  \
# 0               Allan  188652  119765   8517     Botafogo        False
# 1   Gonzalo Mastriani  281240  153330   8517     Botafogo        False
# 2    Marcel Guaramato  423496  166518  49681  Carabobo FC        False
# 3         Alex Telles  428672  152590   8517     Botafogo        False
# 4  Jefferson Savarino  501636  196666   8517     Botafogo        False
#
#                                                stats  \
# 0                                                 []
# 1  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 2                                                 []
# 3  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 4  [{'title': 'Top stats', 'key': 'top_stats', 's...
#
#                                              shotmap  \
# 0                                                 []
# 1  [{'id': 2798416929, 'eventType': 'Miss', 'team...
# 2                                                 []
# 3                                                 []
# 4  [{'id': 2798416179, 'eventType': 'AttemptSaved...
#
#                                             funFacts player_id
# 0                                                 []    188652
# 1                                                 []    281240
# 2                                                 []    423496
# 3                                                 []    428672
# 4  [{'key': 'fun_fact_low_touches', 'fallback': '...    501636

# %%
new_df = df[['teamName', 'player_id']].copy()
new_df
# Out:
#        teamName player_id
# 0      Botafogo    188652
# 1      Botafogo    281240
# 2   Carabobo FC    423496
# 3      Botafogo    428672
# 4      Botafogo    501636
# 5   Carabobo FC    593211
# 6      Botafogo    634868
# 7   Carabobo FC    641140
# 8      Botafogo    657969
# 9      Botafogo    749834
# 10     Botafogo    754504
# 11  Carabobo FC    800702
# 12  Carabobo FC    889539
# 13     Botafogo    905498
# 14     Botafogo    921070
# 15  Carabobo FC    926070
# 16  Carabobo FC   1023077
# 17     Botafogo   1028704
# 18  Carabobo FC   1031644
# 19  Carabobo FC   1124611
# 20     Botafogo   1137664
# 21     Botafogo   1210064
# 22  Carabobo FC   1211302
# 23     Botafogo   1248672
# 24  Carabobo FC   1257669
# 25     Botafogo   1262084
# 26  Carabobo FC   1299971
# 27  Carabobo FC   1330400
# 28     Botafogo   1350129
# 29  Carabobo FC   1353300
# 30  Carabobo FC   1354125
# 31  Carabobo FC   1356175
# 32  Carabobo FC   1363138
# 33  Carabobo FC   1371883
# 34     Botafogo   1373118
# 35     Botafogo   1391209
# 36     Botafogo   1436176
# 37  Carabobo FC   1453231
# 38     Botafogo   1476545
# 39     Botafogo   1578668
# 40  Carabobo FC   1611001
# 41  Carabobo FC   1615062
# 42     Botafogo   1626265
# 43     Botafogo   1732667
# 44  Carabobo FC   1732679
# 45  Carabobo FC   1739032

# %% [markdown]
# Shots

# %%
df_shots = pd.DataFrame(json_fotmob['props']['pageProps']['content']['shotmap']['shots'])
df_shots.head()
# Out:
#            id     eventType  teamId  playerId          playerName          x  \
# 0  2798414113          Miss   49681   1363138     Joshuan Berrios  91.000000
# 1  2798415517          Miss   49681    593211    Gustavo Gonzalez  70.209223
# 2  2798416179  AttemptSaved    8517    501636  Jefferson Savarino  78.205340
# 3  2798416199          Miss    8517   1028704  Santiago Rodriguez  95.640351
# 4  2798416929          Miss    8517    281240   Gonzalo Mastriani  90.400000
#
#            y  min  minAdded  isBlocked  ...     period  isOwnGoal  \
# 0  25.418125    5       NaN      False  ...  FirstHalf      False
# 1  23.718981   10       NaN      False  ...  FirstHalf      False
# 2  28.286905   12       NaN      False  ...  FirstHalf      False
# 3  38.788571   12       NaN      False  ...  FirstHalf      False
# 4  33.618750   15       NaN      False  ...  FirstHalf      False
#
#                                           onGoalShot  isSavedOffLine  \
# 0  {'x': -2.220446049250313e-16, 'y': 0.020534900...           False
# 1  {'x': 0, 'y': 0.030009718309976712, 'zoomRatio...           False
# 2  {'x': 0.9394841269841275, 'y': 0.4195767175132...           False
# 3  {'x': 1.0685432013562148, 'y': 0.6772486772486...           False
# 4  {'x': 1.8956720721422258, 'y': 0.6772486772486...           False
#
#    isFromInsideBox  keeperId  firstName   lastName            fullName  \
# 0             True       NaN    Joshuan    Berrios     Joshuan Berrios
# 1            False       NaN    Gustavo   Gonzalez    Gustavo Gonzalez
# 2            False  800702.0  Jefferson   Savarino  Jefferson Savarino
# 3             True       NaN   Santiago  Rodriguez  Santiago Rodriguez
# 4             True       NaN    Gonzalo  Mastriani   Gonzalo Mastriani
#
#   teamColor
# 0   #551515
# 1   #551515
# 2   #181818
# 3   #181818
# 4   #181818
#
# [5 rows x 29 columns]

# %%
# Add match round to shots DF
df_shots['matchRound'] = matchRound
df_shots.head()
# Out:
#            id     eventType  teamId  playerId          playerName          x  \
# 0  2798414113          Miss   49681   1363138     Joshuan Berrios  91.000000
# 1  2798415517          Miss   49681    593211    Gustavo Gonzalez  70.209223
# 2  2798416179  AttemptSaved    8517    501636  Jefferson Savarino  78.205340
# 3  2798416199          Miss    8517   1028704  Santiago Rodriguez  95.640351
# 4  2798416929          Miss    8517    281240   Gonzalo Mastriani  90.400000
#
#            y  min  minAdded  isBlocked  ...  isOwnGoal  \
# 0  25.418125    5       NaN      False  ...      False
# 1  23.718981   10       NaN      False  ...      False
# 2  28.286905   12       NaN      False  ...      False
# 3  38.788571   12       NaN      False  ...      False
# 4  33.618750   15       NaN      False  ...      False
#
#                                           onGoalShot  isSavedOffLine  \
# 0  {'x': -2.220446049250313e-16, 'y': 0.020534900...           False
# 1  {'x': 0, 'y': 0.030009718309976712, 'zoomRatio...           False
# 2  {'x': 0.9394841269841275, 'y': 0.4195767175132...           False
# 3  {'x': 1.0685432013562148, 'y': 0.6772486772486...           False
# 4  {'x': 1.8956720721422258, 'y': 0.6772486772486...           False
#
#    isFromInsideBox  keeperId  firstName   lastName            fullName  \
# 0             True       NaN    Joshuan    Berrios     Joshuan Berrios
# 1            False       NaN    Gustavo   Gonzalez    Gustavo Gonzalez
# 2            False  800702.0  Jefferson   Savarino  Jefferson Savarino
# 3             True       NaN   Santiago  Rodriguez  Santiago Rodriguez
# 4             True       NaN    Gonzalo  Mastriani   Gonzalo Mastriani
#
#   teamColor matchRound
# 0   #551515          2
# 1   #551515          2
# 2   #181818          2
# 3   #181818          2
# 4   #181818          2
#
# [5 rows x 30 columns]

# %%
new_df['player_id'] = new_df['player_id'].astype(int)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   teamName   46 non-null     object
#  1   player_id  46 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 868.0+ bytes

# %%
h_team
# Out:
# 'Botafogo RJ'

# %%
# Get hpme and away team
# df_shots['h_a'] = df_shots['teamName'].apply(lambda x: 'h' if x == h_team else 'a') # does not work with Botafogo RJ & Botafogo

from fuzzywuzzy import fuzz

# Define a similarity threshold (e.g., 70 means 70% similar)
threshold = 70

df_shots['h_a'] = df_shots['teamName'].apply(
    lambda x: 'h' if fuzz.ratio(x.lower(), h_team.lower()) >= threshold else 'a'
)

df_shots.head()
# Out:
#            id     eventType  teamId  playerId          playerName          x  \
# 0  2798414113          Miss   49681   1363138     Joshuan Berrios  91.000000
# 1  2798415517          Miss   49681    593211    Gustavo Gonzalez  70.209223
# 2  2798416179  AttemptSaved    8517    501636  Jefferson Savarino  78.205340
# 3  2798416199          Miss    8517   1028704  Santiago Rodriguez  95.640351
# 4  2798416929          Miss    8517    281240   Gonzalo Mastriani  90.400000
#
#            y  min  minAdded  isBlocked  ...  isFromInsideBox  keeperId  \
# 0  25.418125    5       NaN      False  ...             True       NaN
# 1  23.718981   10       NaN      False  ...            False       NaN
# 2  28.286905   12       NaN      False  ...            False  800702.0
# 3  38.788571   12       NaN      False  ...             True       NaN
# 4  33.618750   15       NaN      False  ...             True       NaN
#
#    firstName   lastName            fullName  teamColor  matchRound  \
# 0    Joshuan    Berrios     Joshuan Berrios    #551515           2
# 1    Gustavo   Gonzalez    Gustavo Gonzalez    #551515           2
# 2  Jefferson   Savarino  Jefferson Savarino    #181818           2
# 3   Santiago  Rodriguez  Santiago Rodriguez    #181818           2
# 4    Gonzalo  Mastriani   Gonzalo Mastriani    #181818           2
#
#       teamName h_a ho_aw
# 0  Carabobo FC   a     a
# 1  Carabobo FC   a     a
# 2     Botafogo   h     h
# 3     Botafogo   h     h
# 4     Botafogo   h     h
#
# [5 rows x 33 columns]

# %%
# Compare the two dataframes
df_shots['teamName'] = df_shots['playerId'].map(new_df.set_index('player_id')['teamName'])
df_shots
# Out:
#             id     eventType  teamId  playerId          playerName  \
# 0   2798414113          Miss   49681   1363138     Joshuan Berrios
# 1   2798415517          Miss   49681    593211    Gustavo Gonzalez
# 2   2798416179  AttemptSaved    8517    501636  Jefferson Savarino
# 3   2798416199          Miss    8517   1028704  Santiago Rodriguez
# 4   2798416929          Miss    8517    281240   Gonzalo Mastriani
# 5   2798418233  AttemptSaved   49681    593211    Gustavo Gonzalez
# 6   2798418277  AttemptSaved   49681   1023077        Carlos Ramos
# 7   2798418441  AttemptSaved   49681    593211    Gustavo Gonzalez
# 8   2798421907  AttemptSaved    8517   1028704  Santiago Rodriguez
# 9   2798422359          Miss    8517    657969   Alexander Barboza
# 10  2798423689          Miss    8517    754504     Artur Guimaraes
# 11  2798426161  AttemptSaved    8517    501636  Jefferson Savarino
# 12  2798428303          Miss    8517    281240   Gonzalo Mastriani
# 13  2798429715          Miss    8517    657969   Alexander Barboza
# 14  2798433579  AttemptSaved    8517    281240   Gonzalo Mastriani
# 15  2798432025          Post   49681   1356175          Juan Perez
# 16  2798432831  AttemptSaved   49681   1371883       Miguel Pernia
# 17  2798433741  AttemptSaved    8517    501636  Jefferson Savarino
# 18  2798434691          Miss    8517   1137664    Patrick Carneiro
# 19  2798435239          Post    8517    657969   Alexander Barboza
# 20  2798435961  AttemptSaved    8517    501636  Jefferson Savarino
# 21  2798436403          Goal    8517   1137664    Patrick Carneiro
# 22  2798437109          Miss    8517   1476545            Cuiabano
# 23  2798437733  AttemptSaved    8517   1476545            Cuiabano
# 24  2798439221          Goal    8517   1262084     Matheus Martins
#
#              x          y  min  minAdded  isBlocked  ...  \
# 0    91.000000  25.418125    5       NaN      False  ...
# 1    70.209223  23.718981   10       NaN      False  ...
# 2    78.205340  28.286905   12       NaN      False  ...
# 3    95.640351  38.788571   12       NaN      False  ...
# 4    90.400000  33.618750   15       NaN      False  ...
# 5    83.273301  29.547619   20       NaN       True  ...
# 6    77.529612  20.425987   20       NaN       True  ...
# 7    80.683010  33.771250   21       NaN      False  ...
# 8    94.096491  37.355000   33       NaN      False  ...
# 9    70.884951  37.660000   34       NaN      False  ...
# 10   95.061404  26.690000   38       NaN      False  ...
# 11   97.377193  48.344713   45       1.0       True  ...
# 12  100.448276  35.143750   48       NaN      False  ...
# 13   80.007282  42.928750   55       NaN      False  ...
# 14   94.675439  37.780000   65       NaN       True  ...
# 15   87.104412  49.675924   66       NaN      False  ...
# 16   93.600000  25.013438   70       NaN      False  ...
# 17   90.700000  52.198217   75       NaN      False  ...
# 18   74.038350  17.763567   81       NaN      False  ...
# 19  101.965517  28.034762   83       NaN      False  ...
# 20   86.245588  33.237500   86       NaN      False  ...
# 21   75.952913  36.592500   88       NaN      False  ...
# 22   81.358738  39.965238   90       1.0      False  ...
# 23   77.079126  43.720510   90       4.0      False  ...
# 24  100.448276  22.037452   90       8.0      False  ...
#
#                                            onGoalShot  isSavedOffLine  \
# 0   {'x': -2.220446049250313e-16, 'y': 0.020534900...           False
# 1   {'x': 0, 'y': 0.030009718309976712, 'zoomRatio...           False
# 2   {'x': 0.9394841269841275, 'y': 0.4195767175132...           False
# 3   {'x': 1.0685432013562148, 'y': 0.6772486772486...           False
# 4   {'x': 1.8956720721422258, 'y': 0.6772486772486...           False
# 5   {'x': 0.5763888888888888, 'y': 0.3227513211640...           False
# 6   {'x': 0.21329365079365015, 'y': 0.322751321164...           False
# 7   {'x': 0.41501322751322767, 'y': 0.439961011481...           False
# 8   {'x': 0.5360449735449745, 'y': 0.1936507926984...           False
# 9   {'x': 0.43102956755225275, 'y': 0.677248677248...           False
# 10  {'x': 0, 'y': 0.2379341951719582, 'zoomRatio':...           False
# 11  {'x': 1.0403439153439162, 'y': 0.3227513211640...           False
# 12  {'x': 0, 'y': 0.010741632431716715, 'zoomRatio...           False
# 13  {'x': 2, 'y': 0.09884141271830969, 'zoomRatio'...           False
# 14  {'x': 1.3630952380952386, 'y': 0.3227513211640...           False
# 15  {'x': 1.282407407407408, 'y': 0.65026455026455...           False
# 16  {'x': 0.49570105820105825, 'y': 0.494319128730...           False
# 17  {'x': 1.4034391534391548, 'y': 0.1936507926984...           False
# 18  {'x': 2, 'y': 0.20162073782509646, 'zoomRatio'...           False
# 19  {'x': 2, 'y': 0.21573377783068776, 'zoomRatio'...           False
# 20  {'x': 1.0605158730158726, 'y': 0.0747424112169...           False
# 21  {'x': 1.8270502645502642, 'y': 0.1511835135978...           False
# 22  {'x': 0, 'y': 0.32161428773237827, 'zoomRatio'...           False
# 23  {'x': 1.3025793650793662, 'y': 0.0424672791005...           False
# 24  {'x': 1.3630952380952386, 'y': 0.3974937323809...           False
#
#     isFromInsideBox  keeperId  firstName   lastName            fullName  \
# 0              True       NaN    Joshuan    Berrios     Joshuan Berrios
# 1             False       NaN    Gustavo   Gonzalez    Gustavo Gonzalez
# 2             False  800702.0  Jefferson   Savarino  Jefferson Savarino
# 3              True       NaN   Santiago  Rodriguez  Santiago Rodriguez
# 4              True       NaN    Gonzalo  Mastriani   Gonzalo Mastriani
# 5             False       NaN    Gustavo   Gonzalez    Gustavo Gonzalez
# 6             False       NaN     Carlos      Ramos        Carlos Ramos
# 7             False  749834.0    Gustavo   Gonzalez    Gustavo Gonzalez
# 8              True  800702.0   Santiago  Rodriguez  Santiago Rodriguez
# 9             False       NaN  Alexander    Barboza   Alexander Barboza
# 10             True       NaN      Artur  Guimaraes     Artur Guimaraes
# 11             True       NaN  Jefferson   Savarino  Jefferson Savarino
# 12             True       NaN    Gonzalo  Mastriani   Gonzalo Mastriani
# 13            False       NaN  Alexander    Barboza   Alexander Barboza
# 14             True       NaN    Gonzalo  Mastriani   Gonzalo Mastriani
# 15            False       NaN       Juan      Perez          Juan Perez
# 16             True  749834.0     Miguel     Pernia       Miguel Pernia
# 17             True  800702.0  Jefferson   Savarino  Jefferson Savarino
# 18            False       NaN    Patrick   Carneiro    Patrick Carneiro
# 19             True       NaN  Alexander    Barboza   Alexander Barboza
# 20            False  800702.0  Jefferson   Savarino  Jefferson Savarino
# 21            False  800702.0    Patrick   Carneiro    Patrick Carneiro
# 22            False       NaN              Cuiabano            Cuiabano
# 23            False  800702.0              Cuiabano            Cuiabano
# 24             True  800702.0    Matheus    Martins     Matheus Martins
#
#    teamColor matchRound     teamName
# 0    #551515          2  Carabobo FC
# 1    #551515          2  Carabobo FC
# 2    #181818          2     Botafogo
# 3    #181818          2     Botafogo
# 4    #181818          2     Botafogo
# 5    #551515          2  Carabobo FC
# 6    #551515          2  Carabobo FC
# 7    #551515          2  Carabobo FC
# 8    #181818          2     Botafogo
# 9    #181818          2     Botafogo
# 10   #181818          2     Botafogo
# 11   #181818          2     Botafogo
# 12   #181818          2     Botafogo
# 13   #181818          2     Botafogo
# 14   #181818          2     Botafogo
# 15   #551515          2  Carabobo FC
# 16   #551515          2  Carabobo FC
# 17   #181818          2     Botafogo
# 18   #181818          2     Botafogo
# 19   #181818          2     Botafogo
# 20   #181818          2     Botafogo
# 21   #181818          2     Botafogo
# 22   #181818          2     Botafogo
# 23   #181818          2     Botafogo
# 24   #181818          2     Botafogo
#
# [25 rows x 31 columns]

# %%
# Same result as above, but using merge
df_shots = pd.merge(
    df_shots,
    new_df[['player_id', 'teamName']],
    left_on='playerId',
    right_on='player_id',
    how='left'  # keeps all rows from df_shots even if no match
).drop('player_id', axis=1)  # drop the redundant column

df_shots

# %%
# DF to CSV
df_shots.to_csv('/home/axel/Code/Python/axel/streamlit/csv/CerroBolivar.csv', index=False)

# %% [markdown]
# Check concat file

# %%
shots = pd.read_csv('/home/axel/Code/Python/axel/streamlit/concat_files/concat_shots.csv')

# %% [markdown]
# Most shots

# %%
shots['teamName'].value_counts().sort_values(ascending=False)

# teams_df = shots['teamName'].value_counts().reset_index()
# teams_df.columns = ['teamName', 'count']
# teams_df.sort_values(by='count', ascending=False)
# Out:
# teamName
# Racing Club                              24
# Atlético Nacional                        22
# Bahia                                    21
# Palmeiras                                19
# Vélez Sarsfield                          19
# Cerro Porteño                            19
# Talleres de Córdoba                      17
# Central Córdoba (Santiago del Estero)    17
# Barcelona de Guayaquil                   17
# Alianza Lima                             16
# Olimpia                                  15
# Fortaleza EC                             14
# Sporting Cristal                         14
# Estudiantes de La Plata                  14
# San Antonio Bulo Bulo                    14
# Flamengo                                 12
# Atlético Bucaramanga                     12
# Nacional                                 11
# Libertad                                 11
# Bolívar                                  10
# River Plate                              10
# Independiente del Valle                  10
# Colo-Colo                                 9
# Internacional                             8
# Botafogo                                  7
# Universitario de Deportes                 6
# Carabobo FC                               6
# Deportivo Táchira                         6
# Universidad de Chile                      6
# São Paulo                                 5
# LDU Quito                                 5
# Peñarol                                   4
# Name: count, dtype: int64

# %% [markdown]
# Filter by shots on target

# %%
target_shots = shots[shots['isOnTarget'] == True]
target_shots.shape
# Out:
# (238, 31)

# %%
target_shots.groupby('teamName')['isOnTarget'].count().reset_index(name='count').sort_values(by='count', ascending=False).reset_index(drop=True)
# Out:
#                                  teamName  count
# 0                             Racing Club     16
# 1                       Atlético Nacional     14
# 2                         Vélez Sarsfield     12
# 3                  Barcelona de Guayaquil     12
# 4                                   Bahia     11
# 5                               Palmeiras     11
# 6   Central Córdoba (Santiago del Estero)     10
# 7                            Alianza Lima     10
# 8                        Sporting Cristal     10
# 9                     Talleres de Córdoba     10
# 10                  San Antonio Bulo Bulo      9
# 11                                Olimpia      9
# 12                           Fortaleza EC      9
# 13                               Nacional      8
# 14                          Cerro Porteño      8
# 15                   Atlético Bucaramanga      7
# 16                          Internacional      7
# 17                Estudiantes de La Plata      7
# 18                               Flamengo      6
# 19                               Libertad      6
# 20                               Botafogo      6
# 21                                Bolívar      6
# 22                              Colo-Colo      6
# 23                            River Plate      5
# 24              Universitario de Deportes      4
# 25                              São Paulo      4
# 26                            Carabobo FC      4
# 27                Independiente del Valle      3
# 28                   Universidad de Chile      3
# 29                      Deportivo Táchira      2
# 30                              LDU Quito      2
# 31                                Peñarol      1

# %%
shots.columns
# Out:
# Index(['id', 'eventType', 'teamId', 'playerId', 'playerName', 'x', 'y', 'min',
#        'minAdded', 'isBlocked', 'isOnTarget', 'blockedX', 'blockedY',
#        'goalCrossedY', 'goalCrossedZ', 'expectedGoals',
#        'expectedGoalsOnTarget', 'shotType', 'situation', 'period', 'isOwnGoal',
#        'onGoalShot', 'isSavedOffLine', 'isFromInsideBox', 'keeperId',
#        'firstName', 'lastName', 'fullName', 'teamColor', 'teamName',
#        'source_file'],
#       dtype='object')
