# %%
import requests
import json
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = input("Enter the URL of the page to scrape: ")
r = requests.get(url)
soup = bs(r.content)
json_fotmob = json.loads(soup.find('script', attrs={'id': '__NEXT_DATA__'}).contents[0])

# %%
# General match info
json_fotmob['props']['pageProps']['general']
# Out:
# {'matchId': '4756697',
#  'matchName': 'Botafogo RJ-vs-Carabobo FC_Tue, Apr 8, 2025, 22:00 UTC',
#  'matchRound': '2',
#  'teamColors': {'darkMode': {'home': '#ffffff', 'away': '#943521'},
#   'lightMode': {'home': '#181818', 'away': '#551515'},
#   'fontDarkMode': {'home': 'rgba(29, 29, 29, 1.0)',
#    'away': 'rgba(255, 255, 255, 1.0)'},
#   'fontLightMode': {'home': 'rgba(255, 255, 255, 1.0)',
#    'away': 'rgba(255, 255, 255, 1.0)'}},
#  'leagueId': 898417,
#  'leagueName': 'Copa Libertadores Grp. A',
#  'leagueRoundName': '2',
#  'parentLeagueId': 45,
#  'countryCode': 'INT-2',
#  'parentLeagueName': 'Copa Libertadores',
#  'parentLeagueSeason': '2025',
#  'parentLeagueTopScorerLink': 'https://data.fotmob.com/stats/45/season/25464/goals.json',
#  'parentLeagueTournamentId': 25464,
#  'homeTeam': {'name': 'Botafogo RJ', 'id': 8517},
#  'awayTeam': {'name': 'Carabobo FC', 'id': 49681},
#  'coverageLevel': 'xG',
#  'matchTimeUTC': 'Tue, Apr 8, 2025, 22:00 UTC',
#  'matchTimeUTCDate': '2025-04-08T22:00:00.000Z',
#  'started': True,
#  'finished': True}

# %%
matchRound = int(json_fotmob['props']['pageProps']['general']['matchRound'])
matchRound
# Out:
# 2

# %%
type(matchRound)
# Out:
# int

# %%
json_fotmob['props']['pageProps']['general']['homeTeam']['name']
# Out:
# 'Carabobo FC'

# %%
json_fotmob['props']['pageProps']['general']['awayTeam']['name']
# Out:
# 'Carabobo FC'

# %%
df = pd.DataFrame(json_fotmob['props']['pageProps']['content']['playerStats'])
df
# Out:
#                 188652                                             281240  \
# name             Allan                                  Gonzalo Mastriani
# id              188652                                             281240
# optaId          119765                                             153330
# teamId            8517                                               8517
# teamName      Botafogo                                           Botafogo
# isGoalkeeper     False                                              False
# stats               []  [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap             []  [{'id': 2798416929, 'eventType': 'Miss', 'team...
# funFacts            []                                                 []
#
#                         423496  \
# name          Marcel Guaramato
# id                      423496
# optaId                  166518
# teamId                   49681
# teamName           Carabobo FC
# isGoalkeeper             False
# stats                       []
# shotmap                     []
# funFacts                    []
#
#                                                          428672  \
# name                                                Alex Telles
# id                                                       428672
# optaId                                                   152590
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                          501636  \
# name                                         Jefferson Savarino
# id                                                       501636
# optaId                                                   196666
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2798416179, 'eventType': 'AttemptSaved...
# funFacts      [{'key': 'fun_fact_low_touches', 'fallback': '...
#
#                                                          593211  \
# name                                           Gustavo Gonzalez
# id                                                       593211
# optaId                                                   196304
# teamId                                                    49681
# teamName                                            Carabobo FC
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2798415517, 'eventType': 'Miss', 'team...
# funFacts                                                     []
#
#                                                          634868  \
# name                                             Marlon Freitas
# id                                                       634868
# optaId                                                   219357
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                          641140  \
# name                                           Robert Hernandez
# id                                                       641140
# optaId                                                   149237
# teamId                                                    49681
# teamName                                            Carabobo FC
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                          657969  \
# name                                          Alexander Barboza
# id                                                       657969
# optaId                                                   213531
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2798422359, 'eventType': 'Miss', 'team...
# funFacts      [{'key': 'fun_fact_motm', 'fallback': 'Alexand...
#
#                        693358  ...  \
# name          Fernando Garcia  ...
# id                          0  ...
# optaId                 693358  ...
# teamId                  49681  ...
# teamName          Carabobo FC  ...
# isGoalkeeper            False  ...
# stats                      []  ...
# shotmap                    []  ...
# funFacts                  NaN  ...
#
#                                                         1391209  \
# name                                                 Jair Filho
# id                                                      1391209
# optaId                                                   575458
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts      [{'key': 'fun_fact_pass_completion', 'fallback...
#
#                                                         1436176  \
# name                                                Mateo Ponte
# id                                                      1436176
# optaId                                                   609049
# teamId                                                     8517
# teamName                                               Botafogo
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                         1453231  \
# name                                             Ezequiel Neira
# id                                                      1453231
# optaId                                                   502487
# teamId                                                    49681
# teamName                                            Carabobo FC
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                         1476545   1578668  \
# name                                                   Cuiabano    Newton
# id                                                      1476545   1578668
# optaId                                                   560441    608580
# teamId                                                     8517      8517
# teamName                                               Botafogo  Botafogo
# isGoalkeeper                                              False     False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...        []
# shotmap       [{'id': 2798437109, 'eventType': 'Miss', 'team...        []
# funFacts                                                     []        []
#
#                    1611001                                            1615062  \
# name          Freiver Ruiz                                      Franner Lopez
# id                 1611001                                            1615062
# optaId              485122                                             612930
# teamId               49681                                              49681
# teamName       Carabobo FC                                        Carabobo FC
# isGoalkeeper         False                                              False
# stats                   []  [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                 []                                                 []
# funFacts                []                                                 []
#
#                1626265       1732667            1732679
# name              Kaue  Kauan Lindes  Sebastian Mendoza
# id             1626265       1732667            1732679
# optaId          608581        646823             654211
# teamId            8517          8517              49681
# teamName      Botafogo      Botafogo        Carabobo FC
# isGoalkeeper     False         False              False
# stats               []            []                 []
# shotmap             []            []                 []
# funFacts            []            []                 []
#
# [9 rows x 46 columns]

# %%
df = df.T
df.head()
# Out:
#                       name      id  optaId teamId     teamName isGoalkeeper  \
# 188652               Allan  188652  119765   8517     Botafogo        False
# 281240   Gonzalo Mastriani  281240  153330   8517     Botafogo        False
# 423496    Marcel Guaramato  423496  166518  49681  Carabobo FC        False
# 428672         Alex Telles  428672  152590   8517     Botafogo        False
# 501636  Jefferson Savarino  501636  196666   8517     Botafogo        False
#
#                                                     stats  \
# 188652                                                 []
# 281240  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 423496                                                 []
# 428672  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 501636  [{'title': 'Top stats', 'key': 'top_stats', 's...
#
#                                                   shotmap  \
# 188652                                                 []
# 281240  [{'id': 2798416929, 'eventType': 'Miss', 'team...
# 423496                                                 []
# 428672                                                 []
# 501636  [{'id': 2798416179, 'eventType': 'AttemptSaved...
#
#                                                  funFacts
# 188652                                                 []
# 281240                                                 []
# 423496                                                 []
# 428672                                                 []
# 501636  [{'key': 'fun_fact_low_touches', 'fallback': '...

# %%
df['player_id'] = df.index
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#                  name      id  optaId teamId     teamName isGoalkeeper  \
# 0               Allan  188652  119765   8517     Botafogo        False
# 1   Gonzalo Mastriani  281240  153330   8517     Botafogo        False
# 2    Marcel Guaramato  423496  166518  49681  Carabobo FC        False
# 3         Alex Telles  428672  152590   8517     Botafogo        False
# 4  Jefferson Savarino  501636  196666   8517     Botafogo        False
#
#                                                stats  \
# 0                                                 []
# 1  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 2                                                 []
# 3  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 4  [{'title': 'Top stats', 'key': 'top_stats', 's...
#
#                                              shotmap  \
# 0                                                 []
# 1  [{'id': 2798416929, 'eventType': 'Miss', 'team...
# 2                                                 []
# 3                                                 []
# 4  [{'id': 2798416179, 'eventType': 'AttemptSaved...
#
#                                             funFacts player_id
# 0                                                 []    188652
# 1                                                 []    281240
# 2                                                 []    423496
# 3                                                 []    428672
# 4  [{'key': 'fun_fact_low_touches', 'fallback': '...    501636

# %%
new_df = df[['teamName', 'player_id']].copy()
new_df
# Out:
#          teamName player_id
# 0   Cerro Porteño     68422
# 1         Bolívar    113622
# 2         Bolívar    114056
# 3   Cerro Porteño    190669
# 4   Cerro Porteño    202202
# 5   Cerro Porteño    244899
# 6         Bolívar    282514
# 7   Cerro Porteño    315632
# 8         Bolívar    361077
# 9   Cerro Porteño    362238
# 10  Cerro Porteño    467955
# 11  Cerro Porteño    497352
# 12  Cerro Porteño    497395
# 13        Bolívar    530284
# 14  Cerro Porteño    571609
# 15  Cerro Porteño    662089
# 16        Bolívar    684897
# 17  Cerro Porteño    688291
# 18        Bolívar    807776
# 19        Bolívar    813372
# 20        Bolívar    832400
# 21        Bolívar    837887
# 22        Bolívar    840183
# 23  Cerro Porteño    900003
# 24        Bolívar   1003633
# 25        Bolívar   1021946
# 26        Bolívar   1033153
# 27  Cerro Porteño   1074074
# 28        Bolívar   1102243
# 29        Bolívar   1133311
# 30  Cerro Porteño   1255220
# 31        Bolívar   1312460
# 32        Bolívar   1368559
# 33  Cerro Porteño   1458735
# 34  Cerro Porteño   1458741
# 35        Bolívar   1504136
# 36        Bolívar   1560822
# 37        Bolívar   1613569
# 38        Bolívar   1626375
# 39  Cerro Porteño   1634834
# 40  Cerro Porteño   1661695
# 41  Cerro Porteño   1732696
# 42        Bolívar   1736525
# 43  Cerro Porteño   1736530
# 44  Cerro Porteño   1736532
# 45  Cerro Porteño   1736534

# %% [markdown]
# Shots

# %%
df_shots = pd.DataFrame(json_fotmob['props']['pageProps']['content']['shotmap']['shots'])
df_shots.head()
# Out:
#            id     eventType  teamId  playerId          playerName          x  \
# 0  2798414113          Miss   49681   1363138     Joshuan Berrios  91.000000
# 1  2798415517          Miss   49681    593211    Gustavo Gonzalez  70.209223
# 2  2798416179  AttemptSaved    8517    501636  Jefferson Savarino  78.205340
# 3  2798416199          Miss    8517   1028704  Santiago Rodriguez  95.640351
# 4  2798416929          Miss    8517    281240   Gonzalo Mastriani  90.400000
#
#            y  min  minAdded  isBlocked  ...     period  isOwnGoal  \
# 0  25.418125    5       NaN      False  ...  FirstHalf      False
# 1  23.718981   10       NaN      False  ...  FirstHalf      False
# 2  28.286905   12       NaN      False  ...  FirstHalf      False
# 3  38.788571   12       NaN      False  ...  FirstHalf      False
# 4  33.618750   15       NaN      False  ...  FirstHalf      False
#
#                                           onGoalShot  isSavedOffLine  \
# 0  {'x': -2.220446049250313e-16, 'y': 0.020534900...           False
# 1  {'x': 0, 'y': 0.030009718309976712, 'zoomRatio...           False
# 2  {'x': 0.9394841269841275, 'y': 0.4195767175132...           False
# 3  {'x': 1.0685432013562148, 'y': 0.6772486772486...           False
# 4  {'x': 1.8956720721422258, 'y': 0.6772486772486...           False
#
#    isFromInsideBox  keeperId  firstName   lastName            fullName  \
# 0             True       NaN    Joshuan    Berrios     Joshuan Berrios
# 1            False       NaN    Gustavo   Gonzalez    Gustavo Gonzalez
# 2            False  800702.0  Jefferson   Savarino  Jefferson Savarino
# 3             True       NaN   Santiago  Rodriguez  Santiago Rodriguez
# 4             True       NaN    Gonzalo  Mastriani   Gonzalo Mastriani
#
#   teamColor
# 0   #551515
# 1   #551515
# 2   #181818
# 3   #181818
# 4   #181818
#
# [5 rows x 29 columns]

# %%
# Add match round to shots DF
df_shots['matchRound'] = matchRound
df_shots.head()
# Out:
#            id     eventType  teamId  playerId          playerName          x  \
# 0  2798414113          Miss   49681   1363138     Joshuan Berrios  91.000000
# 1  2798415517          Miss   49681    593211    Gustavo Gonzalez  70.209223
# 2  2798416179  AttemptSaved    8517    501636  Jefferson Savarino  78.205340
# 3  2798416199          Miss    8517   1028704  Santiago Rodriguez  95.640351
# 4  2798416929          Miss    8517    281240   Gonzalo Mastriani  90.400000
#
#            y  min  minAdded  isBlocked  ...  isOwnGoal  \
# 0  25.418125    5       NaN      False  ...      False
# 1  23.718981   10       NaN      False  ...      False
# 2  28.286905   12       NaN      False  ...      False
# 3  38.788571   12       NaN      False  ...      False
# 4  33.618750   15       NaN      False  ...      False
#
#                                           onGoalShot  isSavedOffLine  \
# 0  {'x': -2.220446049250313e-16, 'y': 0.020534900...           False
# 1  {'x': 0, 'y': 0.030009718309976712, 'zoomRatio...           False
# 2  {'x': 0.9394841269841275, 'y': 0.4195767175132...           False
# 3  {'x': 1.0685432013562148, 'y': 0.6772486772486...           False
# 4  {'x': 1.8956720721422258, 'y': 0.6772486772486...           False
#
#    isFromInsideBox  keeperId  firstName   lastName            fullName  \
# 0             True       NaN    Joshuan    Berrios     Joshuan Berrios
# 1            False       NaN    Gustavo   Gonzalez    Gustavo Gonzalez
# 2            False  800702.0  Jefferson   Savarino  Jefferson Savarino
# 3             True       NaN   Santiago  Rodriguez  Santiago Rodriguez
# 4             True       NaN    Gonzalo  Mastriani   Gonzalo Mastriani
#
#   teamColor matchRound
# 0   #551515          2
# 1   #551515          2
# 2   #181818          2
# 3   #181818          2
# 4   #181818          2
#
# [5 rows x 30 columns]

# %%
new_df['player_id'] = new_df['player_id'].astype(int)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   teamName   46 non-null     object
#  1   player_id  46 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 868.0+ bytes

# %%
df_shots['teamName'] = df_shots['playerId'].map(new_df.set_index('player_id')['teamName'])
df_shots
# Out:
#             id     eventType  teamId  playerId              playerName  \
# 0   2794779809          Miss    6295    202202        Federico Carrizo
# 1   2794781331          Miss    6295    571609       Guillermo Benitez
# 2   2794782663          Miss    5983    114056      Patricio Rodriguez
# 3   2794783963          Miss    6295    688291             Jorge Morel
# 4   2794784125          Miss    6295   1634834          Gabriel Aguayo
# 5   2794785171  AttemptSaved    5983    282514       Leonel Justiniano
# 6   2794785183  AttemptSaved    5983   1613569          Robson Matheus
# 7   2794785215          Goal    5983    832400             Ramiro Vaca
# 8   2794785929  AttemptSaved    6295    497395            Alan Benitez
# 9   2794786161          Miss    6295    497352       Gustavo Velazquez
# 10  2794786883  AttemptSaved    6295    571609       Guillermo Benitez
# 11  2794787611          Miss    5983    813372           Carlos Melgar
# 12  2794789533          Miss    5983    832400             Ramiro Vaca
# 13  2794792217          Miss    5983   1613569          Robson Matheus
# 14  2794795277  AttemptSaved    6295    497395            Alan Benitez
# 15  2794796013          Goal    6295    662089         Jonathan Torres
# 16  2794800107          Goal    6295    662089         Jonathan Torres
# 17  2794801823          Miss    6295    202202        Federico Carrizo
# 18  2794804233          Miss    6295    662089         Jonathan Torres
# 19  2794806085  AttemptSaved    5983    832400             Ramiro Vaca
# 20  2794806297          Goal    6295    662089         Jonathan Torres
# 21  2794807421          Miss    6295    662089         Jonathan Torres
# 22  2794808937          Miss    6295    190669  Sergio Ezequiel Araujo
# 23  2794809591  AttemptSaved    6295   1634834          Gabriel Aguayo
# 24  2794809803          Miss    6295    497352       Gustavo Velazquez
# 25  2794810427          Goal    6295    688291             Jorge Morel
# 26  2794813423  AttemptSaved    5983   1560822          Jhon Velasquez
# 27  2794816517          Miss    6295    190669  Sergio Ezequiel Araujo
# 28  2794817783          Goal    5983    832400             Ramiro Vaca
#
#              x          y  min  minAdded  isBlocked  ...  isOwnGoal  \
# 0    86.997059  34.000000    2       NaN      False  ...      False
# 1    95.061404  46.172739    5       NaN      False  ...      False
# 2    85.494118  46.032611    9       NaN      False  ...      False
# 3    72.686893  41.599063   13       NaN      False  ...      False
# 4    91.900000  34.838750   14       NaN      False  ...      False
# 5    79.669417  26.774048   17       NaN       True  ...      False
# 6    77.079126  24.279490   17       NaN      False  ...      False
# 7    93.000000  44.140892   17       NaN      False  ...      False
# 8    91.600000  16.782675   20       NaN       True  ...      False
# 9    92.900000  30.292000   20       NaN      False  ...      False
# 10   93.600000  45.261911   23       NaN      False  ...      False
# 11   71.448058  33.847500   25       NaN      False  ...      False
# 12   79.556796  46.032611   31       NaN      False  ...      False
# 13   81.696602  37.355000   38       NaN      False  ...      False
# 14  101.965517  23.298599   45       1.0      False  ...      False
# 15   87.533824  34.381250   45       3.0      False  ...      False
# 16   98.438596  32.551250   47       NaN      False  ...      False
# 17   57.685000  30.051905   50       NaN      False  ...      False
# 18   81.696602  29.883810   56       NaN      False  ...      False
# 19   74.488835  24.955625   60       NaN      False  ...      False
# 20   96.412281  32.322500   61       NaN      False  ...      False
# 21   92.700000  33.542500   63       NaN      False  ...      False
# 22   85.923529  20.425987   68       NaN      False  ...      False
# 23   95.736842  30.051905   70       NaN       True  ...      False
# 24   96.122807  35.677500   70       NaN      False  ...      False
# 25  102.629310  38.872619   72       NaN      False  ...      False
# 26   94.289474  43.720510   79       NaN      False  ...      False
# 27   90.400000  42.581875   86       NaN      False  ...      False
# 28   74.826699  33.695000   89       NaN      False  ...      False
#
#                                            onGoalShot  isSavedOffLine  \
# 0   {'x': 1.4405614101678754, 'y': 0.6772486772486...           False
# 1   {'x': 0.2242015402799874, 'y': 0.6772486772486...           False
# 2   {'x': 0, 'y': 0.05530518860779877, 'zoomRatio'...           False
# 3   {'x': 2, 'y': 0.04009174236917742, 'zoomRatio'...           False
# 4   {'x': 2, 'y': 0.051140953271675595, 'zoomRatio...           False
# 5   {'x': 1.2420634920634936, 'y': 0.3227513211640...           False
# 6   {'x': 0.1729497354497358, 'y': 0.0645502642328...           False
# 7   {'x': 1.7261904761904774, 'y': 0.5045112757142...           False
# 8   {'x': 0.31415343915343885, 'y': 0.095126705185...           False
# 9   {'x': 2, 'y': 0.049190006238030076, 'zoomRatio...           False
# 10  {'x': 0.6772486772486757, 'y': 0.1189083814814...           False
# 11  {'x': 0, 'y': 0.24549018842417628, 'zoomRatio'...           False
# 12  {'x': 1.9268925065067568, 'y': 0.6772486772486...           False
# 13  {'x': 0, 'y': 0.6324475963586048, 'zoomRatio':...           False
# 14  {'x': 1.544642857142858, 'y': 0.38730158539682...           False
# 15  {'x': 0.15277777777777768, 'y': 0.139292675449...           False
# 16  {'x': 1, 'y': 0.11890838148148149, 'zoomRatio'...           False
# 17  {'x': 0, 'y': 0.02357038247253356, 'zoomRatio'...           False
# 18  {'x': 1.278906054012586, 'y': 0.67724867724867...           False
# 19  {'x': 1.2017195767195774, 'y': 0.0424672791005...           False
# 20  {'x': 1.2218915343915355, 'y': 0.2683932039153...           False
# 21  {'x': 1.136255627349229, 'y': 0.67724867724867...           False
# 22  {'x': 0, 'y': 0.13101326895832607, 'zoomRatio'...           False
# 23  {'x': 0.8184523809523807, 'y': 0.3227513211640...           False
# 24  {'x': 1.168467766739125, 'y': 0.67724867724867...           False
# 25  {'x': 0.1729497354497358, 'y': 0.0543581172486...           False
# 26  {'x': 1.4639550264550256, 'y': 0.0968253963492...           False
# 27  {'x': 2, 'y': 0.05305622386348332, 'zoomRatio'...           False
# 28  {'x': 0.15277777777777768, 'y': 0.494319128730...           False
#
#     isFromInsideBox  keeperId        firstName    lastName  \
# 0             False       NaN         Federico     Carrizo
# 1              True       NaN        Guillermo     Benitez
# 2             False       NaN         Patricio   Rodriguez
# 3             False       NaN            Jorge       Morel
# 4              True       NaN          Gabriel      Aguayo
# 5             False       NaN           Leonel  Justiniano
# 6             False   68422.0           Robson     Matheus
# 7              True   68422.0           Ramiro        Vaca
# 8              True       NaN             Alan     Benitez
# 9              True       NaN          Gustavo   Velazquez
# 10             True  361077.0        Guillermo     Benitez
# 11            False       NaN           Carlos      Melgar
# 12            False       NaN           Ramiro        Vaca
# 13            False       NaN           Robson     Matheus
# 14             True  361077.0             Alan     Benitez
# 15            False  361077.0         Jonathan      Torres
# 16             True  361077.0         Jonathan      Torres
# 17            False       NaN         Federico     Carrizo
# 18            False       NaN         Jonathan      Torres
# 19            False   68422.0           Ramiro        Vaca
# 20             True  361077.0         Jonathan      Torres
# 21             True       NaN         Jonathan      Torres
# 22            False       NaN  Sergio Ezequiel      Araujo
# 23             True       NaN          Gabriel      Aguayo
# 24             True       NaN          Gustavo   Velazquez
# 25             True  361077.0            Jorge       Morel
# 26             True   68422.0             Jhon   Velasquez
# 27             True       NaN  Sergio Ezequiel      Araujo
# 28            False   68422.0           Ramiro        Vaca
#
#                   fullName teamColor       teamName
# 0         Federico Carrizo   #CA3638  Cerro Porteño
# 1        Guillermo Benitez   #CA3638  Cerro Porteño
# 2       Patricio Rodriguez   #4ab4dc        Bolívar
# 3              Jorge Morel   #CA3638  Cerro Porteño
# 4           Gabriel Aguayo   #CA3638  Cerro Porteño
# 5        Leonel Justiniano   #4ab4dc        Bolívar
# 6           Robson Matheus   #4ab4dc        Bolívar
# 7              Ramiro Vaca   #4ab4dc        Bolívar
# 8             Alan Benitez   #CA3638  Cerro Porteño
# 9        Gustavo Velazquez   #CA3638  Cerro Porteño
# 10       Guillermo Benitez   #CA3638  Cerro Porteño
# 11           Carlos Melgar   #4ab4dc        Bolívar
# 12             Ramiro Vaca   #4ab4dc        Bolívar
# 13          Robson Matheus   #4ab4dc        Bolívar
# 14            Alan Benitez   #CA3638  Cerro Porteño
# 15         Jonathan Torres   #CA3638  Cerro Porteño
# 16         Jonathan Torres   #CA3638  Cerro Porteño
# 17        Federico Carrizo   #CA3638  Cerro Porteño
# 18         Jonathan Torres   #CA3638  Cerro Porteño
# 19             Ramiro Vaca   #4ab4dc        Bolívar
# 20         Jonathan Torres   #CA3638  Cerro Porteño
# 21         Jonathan Torres   #CA3638  Cerro Porteño
# 22  Sergio Ezequiel Araujo   #CA3638  Cerro Porteño
# 23          Gabriel Aguayo   #CA3638  Cerro Porteño
# 24       Gustavo Velazquez   #CA3638  Cerro Porteño
# 25             Jorge Morel   #CA3638  Cerro Porteño
# 26          Jhon Velasquez   #4ab4dc        Bolívar
# 27  Sergio Ezequiel Araujo   #CA3638  Cerro Porteño
# 28             Ramiro Vaca   #4ab4dc        Bolívar
#
# [29 rows x 30 columns]

# %%
# Same result as above, but using merge
df_shots = pd.merge(
    df_shots,
    new_df[['player_id', 'teamName']],
    left_on='playerId',
    right_on='player_id',
    how='left'  # keeps all rows from df_shots even if no match
).drop('player_id', axis=1)  # drop the redundant column

df_shots

# %%
# DF to CSV
df_shots.to_csv('/home/axel/Code/Python/axel/streamlit/csv/CerroBolivar.csv', index=False)

# %% [markdown]
# Check concat file

# %%
shots = pd.read_csv('/home/axel/Code/Python/axel/streamlit/concat_files/concat_shots.csv')

# %% [markdown]
# Most shots

# %%
shots['teamName'].value_counts().sort_values(ascending=False)

# teams_df = shots['teamName'].value_counts().reset_index()
# teams_df.columns = ['teamName', 'count']
# teams_df.sort_values(by='count', ascending=False)
# Out:
# teamName
# Racing Club                              24
# Atlético Nacional                        22
# Bahia                                    21
# Palmeiras                                19
# Vélez Sarsfield                          19
# Cerro Porteño                            19
# Talleres de Córdoba                      17
# Central Córdoba (Santiago del Estero)    17
# Barcelona de Guayaquil                   17
# Alianza Lima                             16
# Olimpia                                  15
# Fortaleza EC                             14
# Sporting Cristal                         14
# Estudiantes de La Plata                  14
# San Antonio Bulo Bulo                    14
# Flamengo                                 12
# Atlético Bucaramanga                     12
# Nacional                                 11
# Libertad                                 11
# Bolívar                                  10
# River Plate                              10
# Independiente del Valle                  10
# Colo-Colo                                 9
# Internacional                             8
# Botafogo                                  7
# Universitario de Deportes                 6
# Carabobo FC                               6
# Deportivo Táchira                         6
# Universidad de Chile                      6
# São Paulo                                 5
# LDU Quito                                 5
# Peñarol                                   4
# Name: count, dtype: int64

# %% [markdown]
# Filter by shots on target

# %%
target_shots = shots[shots['isOnTarget'] == True]
target_shots.shape
# Out:
# (238, 31)

# %%
target_shots.groupby('teamName')['isOnTarget'].count().reset_index(name='count').sort_values(by='count', ascending=False).reset_index(drop=True)
# Out:
#                                  teamName  count
# 0                             Racing Club     16
# 1                       Atlético Nacional     14
# 2                         Vélez Sarsfield     12
# 3                  Barcelona de Guayaquil     12
# 4                                   Bahia     11
# 5                               Palmeiras     11
# 6   Central Córdoba (Santiago del Estero)     10
# 7                            Alianza Lima     10
# 8                        Sporting Cristal     10
# 9                     Talleres de Córdoba     10
# 10                  San Antonio Bulo Bulo      9
# 11                                Olimpia      9
# 12                           Fortaleza EC      9
# 13                               Nacional      8
# 14                          Cerro Porteño      8
# 15                   Atlético Bucaramanga      7
# 16                          Internacional      7
# 17                Estudiantes de La Plata      7
# 18                               Flamengo      6
# 19                               Libertad      6
# 20                               Botafogo      6
# 21                                Bolívar      6
# 22                              Colo-Colo      6
# 23                            River Plate      5
# 24              Universitario de Deportes      4
# 25                              São Paulo      4
# 26                            Carabobo FC      4
# 27                Independiente del Valle      3
# 28                   Universidad de Chile      3
# 29                      Deportivo Táchira      2
# 30                              LDU Quito      2
# 31                                Peñarol      1

# %%
shots.columns
# Out:
# Index(['id', 'eventType', 'teamId', 'playerId', 'playerName', 'x', 'y', 'min',
#        'minAdded', 'isBlocked', 'isOnTarget', 'blockedX', 'blockedY',
#        'goalCrossedY', 'goalCrossedZ', 'expectedGoals',
#        'expectedGoalsOnTarget', 'shotType', 'situation', 'period', 'isOwnGoal',
#        'onGoalShot', 'isSavedOffLine', 'isFromInsideBox', 'keeperId',
#        'firstName', 'lastName', 'fullName', 'teamColor', 'teamName',
#        'source_file'],
#       dtype='object')
