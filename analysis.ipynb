# %%
import requests
import json
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = input("Enter the URL of the page to scrape: ")
r = requests.get(url)
soup = bs(r.content)
json_fotmob = json.loads(soup.find('script', attrs={'id': '__NEXT_DATA__'}).contents[0])

# %%
df = pd.DataFrame(json_fotmob['props']['pageProps']['content']['playerStats'])
df
# Out:
#                                                           68422  \
# name                                          Roberto Fernandez
# id                                                        68422
# optaId                                                    86809
# teamId                                                     6295
# teamName                                          Cerro Porteño
# isGoalkeeper                                               True
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                          113622  \
# name                                        Miguel Angel Torren
# id                                                       113622
# optaId                                                    86064
# teamId                                                     5983
# teamName                                                Bolívar
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                          114056  \
# name                                         Patricio Rodriguez
# id                                                       114056
# optaId                                                    57175
# teamId                                                     5983
# teamName                                                Bolívar
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2794782663, 'eventType': 'Miss', 'team...
# funFacts                                                     []
#
#                                                          190669  \
# name                                     Sergio Ezequiel Araujo
# id                                                       190669
# optaId                                                    86949
# teamId                                                     6295
# teamName                                          Cerro Porteño
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2794808937, 'eventType': 'Miss', 'team...
# funFacts                                                     []
#
#                                                          202202  \
# name                                           Federico Carrizo
# id                                                       202202
# optaId                                                   167215
# teamId                                                     6295
# teamName                                          Cerro Porteño
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2794779809, 'eventType': 'Miss', 'team...
# funFacts      [{'key': 'fun_fact_fk_foul_won', 'fallback': '...
#
#                                                          244899  \
# name                                               Robert Piris
# id                                                       244899
# optaId                                                   214528
# teamId                                                     6295
# teamName                                          Cerro Porteño
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                          282514  \
# name                                          Leonel Justiniano
# id                                                       282514
# optaId                                                   149381
# teamId                                                     5983
# teamName                                                Bolívar
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2794785171, 'eventType': 'AttemptSaved...
# funFacts                                                     []
#
#                                                          315632  \
# name                                               Bruno Valdez
# id                                                       315632
# optaId                                                   195019
# teamId                                                     6295
# teamName                                          Cerro Porteño
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts                                                     []
#
#                                                          361077  \
# name                                       Federico Lanzillotta
# id                                                       361077
# optaId                                                   191975
# teamId                                                     5983
# teamName                                                Bolívar
# isGoalkeeper                                               True
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap                                                      []
# funFacts      [{'key': 'fun_fact_pass_completion', 'fallback...
#
#                                                          362238  ...  \
# name                                     Gaston Claudio Gimenez  ...
# id                                                       362238  ...
# optaId                                                   169707  ...
# teamId                                                     6295  ...
# teamName                                          Cerro Porteño  ...
# isGoalkeeper                                              False  ...
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...  ...
# shotmap                                                      []  ...
# funFacts                                                     []  ...
#
#                                                         1560822  \
# name                                             Jhon Velasquez
# id                                                      1560822
# optaId                                                   568085
# teamId                                                     5983
# teamName                                                Bolívar
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2794813423, 'eventType': 'AttemptSaved...
# funFacts                                                     []
#
#                                                         1613569       1626375  \
# name                                             Robson Matheus  Bruno Mendez
# id                                                      1613569       1626375
# optaId                                                   480028        616599
# teamId                                                     5983          5983
# teamName                                                Bolívar       Bolívar
# isGoalkeeper                                              False         False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...            []
# shotmap       [{'id': 2794785183, 'eventType': 'AttemptSaved...            []
# funFacts                                                     []            []
#
#                                                         1634834  \
# name                                             Gabriel Aguayo
# id                                                      1634834
# optaId                                                   575494
# teamId                                                     6295
# teamName                                          Cerro Porteño
# isGoalkeeper                                              False
# stats         [{'title': 'Top stats', 'key': 'top_stats', 's...
# shotmap       [{'id': 2794784125, 'eventType': 'Miss', 'team...
# funFacts                                                     []
#
#                     1661695        1732696           1736525        1736530  \
# name             Diego Leon  Carlos Favero  Escleizon Freita   Ariel Avalos
# id                  1661695        1732696           1736525        1736530
# optaId               661712         653610            648893         575488
# teamId                 6295           6295              5983           6295
# teamName      Cerro Porteño  Cerro Porteño           Bolívar  Cerro Porteño
# isGoalkeeper          False          False             False          False
# stats                    []             []                []             []
# shotmap                  []             []                []             []
# funFacts                 []             []                []             []
#
#                       1736532        1736534
# name          Nelson Eliseche  Rodrigo Gomez
# id                    1736532        1736534
# optaId                 688145         616439
# teamId                   6295           6295
# teamName        Cerro Porteño  Cerro Porteño
# isGoalkeeper            False          False
# stats                      []             []
# shotmap                    []             []
# funFacts                   []             []
#
# [9 rows x 46 columns]

# %%
df = df.T
df.head()
# Out:
#                           name      id  optaId teamId       teamName  \
# 68422        Roberto Fernandez   68422   86809   6295  Cerro Porteño
# 113622     Miguel Angel Torren  113622   86064   5983        Bolívar
# 114056      Patricio Rodriguez  114056   57175   5983        Bolívar
# 190669  Sergio Ezequiel Araujo  190669   86949   6295  Cerro Porteño
# 202202        Federico Carrizo  202202  167215   6295  Cerro Porteño
#
#        isGoalkeeper                                              stats  \
# 68422          True  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 113622        False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 114056        False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 190669        False  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 202202        False  [{'title': 'Top stats', 'key': 'top_stats', 's...
#
#                                                   shotmap  \
# 68422                                                  []
# 113622                                                 []
# 114056  [{'id': 2794782663, 'eventType': 'Miss', 'team...
# 190669  [{'id': 2794808937, 'eventType': 'Miss', 'team...
# 202202  [{'id': 2794779809, 'eventType': 'Miss', 'team...
#
#                                                  funFacts
# 68422                                                  []
# 113622                                                 []
# 114056                                                 []
# 190669                                                 []
# 202202  [{'key': 'fun_fact_fk_foul_won', 'fallback': '...

# %%
df['player_id'] = df.index
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#                      name      id  optaId teamId       teamName isGoalkeeper  \
# 0       Roberto Fernandez   68422   86809   6295  Cerro Porteño         True
# 1     Miguel Angel Torren  113622   86064   5983        Bolívar        False
# 2      Patricio Rodriguez  114056   57175   5983        Bolívar        False
# 3  Sergio Ezequiel Araujo  190669   86949   6295  Cerro Porteño        False
# 4        Federico Carrizo  202202  167215   6295  Cerro Porteño        False
#
#                                                stats  \
# 0  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 1  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 2  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 3  [{'title': 'Top stats', 'key': 'top_stats', 's...
# 4  [{'title': 'Top stats', 'key': 'top_stats', 's...
#
#                                              shotmap  \
# 0                                                 []
# 1                                                 []
# 2  [{'id': 2794782663, 'eventType': 'Miss', 'team...
# 3  [{'id': 2794808937, 'eventType': 'Miss', 'team...
# 4  [{'id': 2794779809, 'eventType': 'Miss', 'team...
#
#                                             funFacts player_id
# 0                                                 []     68422
# 1                                                 []    113622
# 2                                                 []    114056
# 3                                                 []    190669
# 4  [{'key': 'fun_fact_fk_foul_won', 'fallback': '...    202202

# %% [markdown]
# Shots

# %%
df_shots = pd.DataFrame(json_fotmob['props']['pageProps']['content']['shotmap']['shots'])
df_shots.head()
# Out:
#            id eventType  teamId  playerId          playerName          x  \
# 0  2794779809      Miss    6295    202202    Federico Carrizo  86.997059
# 1  2794781331      Miss    6295    571609   Guillermo Benitez  95.061404
# 2  2794782663      Miss    5983    114056  Patricio Rodriguez  85.494118
# 3  2794783963      Miss    6295    688291         Jorge Morel  72.686893
# 4  2794784125      Miss    6295   1634834      Gabriel Aguayo  91.900000
#
#            y  min  minAdded  isBlocked  ...     period  isOwnGoal  \
# 0  34.000000    2       NaN      False  ...  FirstHalf      False
# 1  46.172739    5       NaN      False  ...  FirstHalf      False
# 2  46.032611    9       NaN      False  ...  FirstHalf      False
# 3  41.599063   13       NaN      False  ...  FirstHalf      False
# 4  34.838750   14       NaN      False  ...  FirstHalf      False
#
#                                           onGoalShot  isSavedOffLine  \
# 0  {'x': 1.4405614101678754, 'y': 0.6772486772486...           False
# 1  {'x': 0.2242015402799874, 'y': 0.6772486772486...           False
# 2  {'x': 0, 'y': 0.05530518860779877, 'zoomRatio'...           False
# 3  {'x': 2, 'y': 0.04009174236917742, 'zoomRatio'...           False
# 4  {'x': 2, 'y': 0.051140953271675595, 'zoomRatio...           False
#
#    isFromInsideBox  keeperId  firstName   lastName            fullName  \
# 0            False       NaN   Federico    Carrizo    Federico Carrizo
# 1             True       NaN  Guillermo    Benitez   Guillermo Benitez
# 2            False       NaN   Patricio  Rodriguez  Patricio Rodriguez
# 3            False       NaN      Jorge      Morel         Jorge Morel
# 4             True       NaN    Gabriel     Aguayo      Gabriel Aguayo
#
#   teamColor
# 0   #CA3638
# 1   #CA3638
# 2   #4ab4dc
# 3   #CA3638
# 4   #CA3638
#
# [5 rows x 29 columns]

# %%
df_shots
# Out:
#             id     eventType  teamId  playerId              playerName  \
# 0   2794779809          Miss    6295    202202        Federico Carrizo
# 1   2794781331          Miss    6295    571609       Guillermo Benitez
# 2   2794782663          Miss    5983    114056      Patricio Rodriguez
# 3   2794783963          Miss    6295    688291             Jorge Morel
# 4   2794784125          Miss    6295   1634834          Gabriel Aguayo
# 5   2794785171  AttemptSaved    5983    282514       Leonel Justiniano
# 6   2794785183  AttemptSaved    5983   1613569          Robson Matheus
# 7   2794785215          Goal    5983    832400             Ramiro Vaca
# 8   2794785929  AttemptSaved    6295    497395            Alan Benitez
# 9   2794786161          Miss    6295    497352       Gustavo Velazquez
# 10  2794786883  AttemptSaved    6295    571609       Guillermo Benitez
# 11  2794787611          Miss    5983    813372           Carlos Melgar
# 12  2794789533          Miss    5983    832400             Ramiro Vaca
# 13  2794792217          Miss    5983   1613569          Robson Matheus
# 14  2794795277  AttemptSaved    6295    497395            Alan Benitez
# 15  2794796013          Goal    6295    662089         Jonathan Torres
# 16  2794800107          Goal    6295    662089         Jonathan Torres
# 17  2794801823          Miss    6295    202202        Federico Carrizo
# 18  2794804233          Miss    6295    662089         Jonathan Torres
# 19  2794806085  AttemptSaved    5983    832400             Ramiro Vaca
# 20  2794806297          Goal    6295    662089         Jonathan Torres
# 21  2794807421          Miss    6295    662089         Jonathan Torres
# 22  2794808937          Miss    6295    190669  Sergio Ezequiel Araujo
# 23  2794809591  AttemptSaved    6295   1634834          Gabriel Aguayo
# 24  2794809803          Miss    6295    497352       Gustavo Velazquez
# 25  2794810427          Goal    6295    688291             Jorge Morel
# 26  2794813423  AttemptSaved    5983   1560822          Jhon Velasquez
# 27  2794816517          Miss    6295    190669  Sergio Ezequiel Araujo
# 28  2794817783          Goal    5983    832400             Ramiro Vaca
#
#              x          y  min  minAdded  isBlocked  ...      period  \
# 0    86.997059  34.000000    2       NaN      False  ...   FirstHalf
# 1    95.061404  46.172739    5       NaN      False  ...   FirstHalf
# 2    85.494118  46.032611    9       NaN      False  ...   FirstHalf
# 3    72.686893  41.599063   13       NaN      False  ...   FirstHalf
# 4    91.900000  34.838750   14       NaN      False  ...   FirstHalf
# 5    79.669417  26.774048   17       NaN       True  ...   FirstHalf
# 6    77.079126  24.279490   17       NaN      False  ...   FirstHalf
# 7    93.000000  44.140892   17       NaN      False  ...   FirstHalf
# 8    91.600000  16.782675   20       NaN       True  ...   FirstHalf
# 9    92.900000  30.292000   20       NaN      False  ...   FirstHalf
# 10   93.600000  45.261911   23       NaN      False  ...   FirstHalf
# 11   71.448058  33.847500   25       NaN      False  ...   FirstHalf
# 12   79.556796  46.032611   31       NaN      False  ...   FirstHalf
# 13   81.696602  37.355000   38       NaN      False  ...   FirstHalf
# 14  101.965517  23.298599   45       1.0      False  ...   FirstHalf
# 15   87.533824  34.381250   45       3.0      False  ...   FirstHalf
# 16   98.438596  32.551250   47       NaN      False  ...  SecondHalf
# 17   57.685000  30.051905   50       NaN      False  ...  SecondHalf
# 18   81.696602  29.883810   56       NaN      False  ...  SecondHalf
# 19   74.488835  24.955625   60       NaN      False  ...  SecondHalf
# 20   96.412281  32.322500   61       NaN      False  ...  SecondHalf
# 21   92.700000  33.542500   63       NaN      False  ...  SecondHalf
# 22   85.923529  20.425987   68       NaN      False  ...  SecondHalf
# 23   95.736842  30.051905   70       NaN       True  ...  SecondHalf
# 24   96.122807  35.677500   70       NaN      False  ...  SecondHalf
# 25  102.629310  38.872619   72       NaN      False  ...  SecondHalf
# 26   94.289474  43.720510   79       NaN      False  ...  SecondHalf
# 27   90.400000  42.581875   86       NaN      False  ...  SecondHalf
# 28   74.826699  33.695000   89       NaN      False  ...  SecondHalf
#
#     isOwnGoal                                         onGoalShot  \
# 0       False  {'x': 1.4405614101678754, 'y': 0.6772486772486...
# 1       False  {'x': 0.2242015402799874, 'y': 0.6772486772486...
# 2       False  {'x': 0, 'y': 0.05530518860779877, 'zoomRatio'...
# 3       False  {'x': 2, 'y': 0.04009174236917742, 'zoomRatio'...
# 4       False  {'x': 2, 'y': 0.051140953271675595, 'zoomRatio...
# 5       False  {'x': 1.2420634920634936, 'y': 0.3227513211640...
# 6       False  {'x': 0.1729497354497358, 'y': 0.0645502642328...
# 7       False  {'x': 1.7261904761904774, 'y': 0.5045112757142...
# 8       False  {'x': 0.31415343915343885, 'y': 0.095126705185...
# 9       False  {'x': 2, 'y': 0.049190006238030076, 'zoomRatio...
# 10      False  {'x': 0.6772486772486757, 'y': 0.1189083814814...
# 11      False  {'x': 0, 'y': 0.24549018842417628, 'zoomRatio'...
# 12      False  {'x': 1.9268925065067568, 'y': 0.6772486772486...
# 13      False  {'x': 0, 'y': 0.6324475963586048, 'zoomRatio':...
# 14      False  {'x': 1.544642857142858, 'y': 0.38730158539682...
# 15      False  {'x': 0.15277777777777768, 'y': 0.139292675449...
# 16      False  {'x': 1, 'y': 0.11890838148148149, 'zoomRatio'...
# 17      False  {'x': 0, 'y': 0.02357038247253356, 'zoomRatio'...
# 18      False  {'x': 1.278906054012586, 'y': 0.67724867724867...
# 19      False  {'x': 1.2017195767195774, 'y': 0.0424672791005...
# 20      False  {'x': 1.2218915343915355, 'y': 0.2683932039153...
# 21      False  {'x': 1.136255627349229, 'y': 0.67724867724867...
# 22      False  {'x': 0, 'y': 0.13101326895832607, 'zoomRatio'...
# 23      False  {'x': 0.8184523809523807, 'y': 0.3227513211640...
# 24      False  {'x': 1.168467766739125, 'y': 0.67724867724867...
# 25      False  {'x': 0.1729497354497358, 'y': 0.0543581172486...
# 26      False  {'x': 1.4639550264550256, 'y': 0.0968253963492...
# 27      False  {'x': 2, 'y': 0.05305622386348332, 'zoomRatio'...
# 28      False  {'x': 0.15277777777777768, 'y': 0.494319128730...
#
#     isSavedOffLine  isFromInsideBox  keeperId        firstName    lastName  \
# 0            False            False       NaN         Federico     Carrizo
# 1            False             True       NaN        Guillermo     Benitez
# 2            False            False       NaN         Patricio   Rodriguez
# 3            False            False       NaN            Jorge       Morel
# 4            False             True       NaN          Gabriel      Aguayo
# 5            False            False       NaN           Leonel  Justiniano
# 6            False            False   68422.0           Robson     Matheus
# 7            False             True   68422.0           Ramiro        Vaca
# 8            False             True       NaN             Alan     Benitez
# 9            False             True       NaN          Gustavo   Velazquez
# 10           False             True  361077.0        Guillermo     Benitez
# 11           False            False       NaN           Carlos      Melgar
# 12           False            False       NaN           Ramiro        Vaca
# 13           False            False       NaN           Robson     Matheus
# 14           False             True  361077.0             Alan     Benitez
# 15           False            False  361077.0         Jonathan      Torres
# 16           False             True  361077.0         Jonathan      Torres
# 17           False            False       NaN         Federico     Carrizo
# 18           False            False       NaN         Jonathan      Torres
# 19           False            False   68422.0           Ramiro        Vaca
# 20           False             True  361077.0         Jonathan      Torres
# 21           False             True       NaN         Jonathan      Torres
# 22           False            False       NaN  Sergio Ezequiel      Araujo
# 23           False             True       NaN          Gabriel      Aguayo
# 24           False             True       NaN          Gustavo   Velazquez
# 25           False             True  361077.0            Jorge       Morel
# 26           False             True   68422.0             Jhon   Velasquez
# 27           False             True       NaN  Sergio Ezequiel      Araujo
# 28           False            False   68422.0           Ramiro        Vaca
#
#                   fullName teamColor
# 0         Federico Carrizo   #CA3638
# 1        Guillermo Benitez   #CA3638
# 2       Patricio Rodriguez   #4ab4dc
# 3              Jorge Morel   #CA3638
# 4           Gabriel Aguayo   #CA3638
# 5        Leonel Justiniano   #4ab4dc
# 6           Robson Matheus   #4ab4dc
# 7              Ramiro Vaca   #4ab4dc
# 8             Alan Benitez   #CA3638
# 9        Gustavo Velazquez   #CA3638
# 10       Guillermo Benitez   #CA3638
# 11           Carlos Melgar   #4ab4dc
# 12             Ramiro Vaca   #4ab4dc
# 13          Robson Matheus   #4ab4dc
# 14            Alan Benitez   #CA3638
# 15         Jonathan Torres   #CA3638
# 16         Jonathan Torres   #CA3638
# 17        Federico Carrizo   #CA3638
# 18         Jonathan Torres   #CA3638
# 19             Ramiro Vaca   #4ab4dc
# 20         Jonathan Torres   #CA3638
# 21         Jonathan Torres   #CA3638
# 22  Sergio Ezequiel Araujo   #CA3638
# 23          Gabriel Aguayo   #CA3638
# 24       Gustavo Velazquez   #CA3638
# 25             Jorge Morel   #CA3638
# 26          Jhon Velasquez   #4ab4dc
# 27  Sergio Ezequiel Araujo   #CA3638
# 28             Ramiro Vaca   #4ab4dc
#
# [29 rows x 29 columns]
